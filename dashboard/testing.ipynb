# %%
from shared import student_trends_df, staffing_df

# %%
student_trends_df.shape
# Out:
# (104, 18)

# %%
student_staffing_df = staffing_df[staffing_df['employee_type'] == 'student']
student_staffing_df = student_staffing_df[student_staffing_df['date'] == student_staffing_df['date'].max()]
print(student_staffing_df.shape)

student_staffing_df.to_csv('student_staffing_df.csv', index=False)
student_staffing_df
# Out:
# (43, 15)
#              ID            full_name  ...  cdl cdl_training_start_date
# 2382  500666641   Matthew Swearingen  ...  1.0              2026-06-09
# 2383  500635005      Yuan Shuo Chang  ...  0.0              2025-08-18
# 2384  500646501         Zachary Buhr  ...  1.0              2025-02-14
# 2385  500715582            Yunong Wu  ...  0.0                     NaN
# 2386  500657467           Adil Zafar  ...  0.0                     NaN
# 2387  500678557           Yujie Yang  ...  0.0                     NaN
# 2388  500734219            Ean Bowie  ...  0.0                     NaN
# 2389  500788162            Kainan Li  ...  0.0              2024-03-14
# 2390  500765311       Olivia McGrath  ...  1.0              2024-08-20
# 2391  500663430        Julien Lovitz  ...  1.0              2024-10-28
# 2392  500820909        Oliver Shores  ...  0.0              2026-06-29
# 2393  500793864           Jason Barr  ...  1.0              2026-03-24
# ...

# %%
student_trends_df = student_trends_df[student_trends_df['date'] == student_trends_df['date'].max()]
student_trends_df = student_trends_df[student_trends_df['active'] == 1]
print(student_trends_df.shape)

student_trends_df.to_csv('student_trends_df.csv', index=False)
student_trends_df
# Out:
# (45, 18)
#                   full_name  ...  cdl_status
# 2                Adil Zafar  ...         NaN
# 6               Laura Adair  ...         NaN
# 16            Manny Verzola  ...         NaN
# 33            Darrell Zhang  ...         NaN
# 36           Justin Higgins  ...         NaN
# 43           Rodrigo Flores  ...         NaN
# 45              Mikai Thiam  ...         NaN
# 50           Jackson O'Hara  ...         NaN
# 51      Florin Socol-Boeriu  ...         NaN
# 52             Noah Pierron  ...         NaN
# 54       Glauco Fontgalland  ...         NaN
# 55       Matthew Swearingen  ...         NaN
# 57               Anna Irwin  ...         NaN
# 58        Mohamed Abdisalam  ...         NaN
# 59              Sam McQuate  ...         NaN
# 60              Nate Miller  ...         NaN
# 61         Ibrahim Alhassan  ...         NaN
# 62             John DeHaven  ...         NaN
# 63         Christian Geiman  ...         NaN
# 64               Jason Barr  ...         NaN
# ...

# %%
import pandas as pd
path = 'C:/Users/morgan.1461/OneDrive - The Ohio State University/Training & Staffing Master.xlsx.url'

df = pd.read_excel(path, sheet_name='Students')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2 path = 'C:/Users/morgan.1461/OneDrive - The Ohio State University/Training & Staffing Master.xlsx.url'
# ----> 4 df = pd.read_excel(path, sheet_name='Students')
#
# File c:\Users\morgan.1461\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
# ...
